# %% [markdown]
# # Code to generate SR images with the HAT network

# %%
import os
import torch

print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 1.13.1+cu117
# True

# %%
os.system("python /datadrive/AACS2023/HAT/HAT/hat/test.py -opt /datadrive/AACS2023/HAT/HAT/options/test/HAT_SRx4_ImageNet-LR.yml")
# Out:
# Disable distributed.
# 2023-05-09 14:59:52,752 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
#    / / __ / __ \ / __ \ / __  /  / /   / / / // ___// //_/  / /
#   / /_/ // /_/ // /_/ // /_/ /  / /___/ /_/ // /__ / /<    /_/
#   \____/ \____/ \____/ \____/  /_____/\____/ \___//_/|_|  (_)
#
# Version Information:
# 	BasicSR: 1.3.4.9
# 	PyTorch: 1.13.1+cu117
# 	TorchVision: 0.14.1+cu117
# 2023-05-09 14:59:52,752 INFO:
#   name: HAT_SRx4_ImageNet-LR
#   model_type: HATModel
#   scale: 4
#   num_gpu: 4
#   manual_seed: 0
#   tile:[
#     tile_size: 512
#     tile_pad: 32
#   ]
#   datasets:[
#     test_1:[
# ...
